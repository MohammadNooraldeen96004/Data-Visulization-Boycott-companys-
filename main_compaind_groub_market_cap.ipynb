# %% [markdown]
# #

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel(r"C:\Users\mohammad alsarese\OneDrive - Tafila Technical University\Market_Cap_Pepsico2 (1).xlsx")

df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df.dropna(subset=['Date'], inplace=True)

df['Date'] = pd.to_datetime(df['Date'])

df.dropna(subset=['Date'], inplace=True)

df['Date'] = pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'],df['Cap'], marker='o', linestyle='-', color='b', label='Market Cap')
plt.show()

# %%
df.head()
# Out:
#         Date     Cap  rate of change
# 0 2021-01-03  195.39             NaN
# 1 2021-02-12  184.69       -5.476227
# 2 2021-03-31  195.21        5.696031
# 3 2021-04-30  199.18        2.033707
# 4 2021-05-21  203.24        2.038357

# %%
df.head(100)
df.to_csv("Rate of Change in Market")

# %%
df2.head()
# Out:
#         Date    Cap  rate of change            Company
# 0 2021-01-01  317.0             NaN  nastle-cap-hisory
# 1 2021-02-02  295.4       -6.813880  nastle-cap-hisory
# 2 2021-03-03  315.0        6.635071  nastle-cap-hisory
# 3 2021-04-04  337.3        7.079365  nastle-cap-hisory
# 4 2021-05-05  346.3        2.668248  nastle-cap-hisory

# %%
aid_df=pd.read_excel(r"C:\Users\mohammad alsarese\OneDrive - Tafila Technical University\USA_Aid.xlsx")
aid_df.head(10)
# Out:
#         year    Total_Aid                                              Notes
# 0  1949-1966    143000000     Mainly economic aid and loans for development.
# 1       1971    574000000      Aid increased following the 1967 Six-Day War.
# 2       1979   2580000000  After the Camp David Accords, aid significantl...
# 3       1998   3000000000  Israel began phasing out economic aid, focusin...
# 4       2007   3420000000  Start of 10-year Memorandum of Understanding (...
# 5       2016   3840000000  New MoU for $38 billion over 10 years (2019-20...
# 6       2022   4260000000  Includes $500 million for missile defense syst...
# 7       2023   4680000000  Includes missile defense aid as part of Obama-...
# 8       2024  14300000000  Emergency aid following October 2023 conflict,...

# %%
ax5 = sns.barplot(aid_df, x='year', y='Total_Aid', hue='year', legend=False,palette='Blues')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_: f'{x / 1e9:.1f} B'))
plt.title("Total Aid by Year")
plt.xlabel("Year")
plt.ylabel("Total Aid (in Billion)")
plt.xticks(rotation=45)  
plt.show()

# %%
tax_paymentts_pipseco_df=pd.read_excel(r"C:\Users\mohammad alsarese\OneDrive - Tafila Technical University\tax_paymentts_pipseco.xlsx")

# %%
plt.figure(figsize=(12, 8))
ax3=sns.barplot(tax_paymentts_pipseco_df,x='year',y='Tax_Payments(USD)',hue='year',palette='Blues',legend=False)
plt.title("PepsiCo Income Taxes 2010-2024")
plt.xlabel("year 2010 - 2024")
plt.ylabel("PepsiCo Income Taxes ( in Billion )")
plt.show()
